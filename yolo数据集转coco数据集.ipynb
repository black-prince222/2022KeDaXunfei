# %%
import os
import cv2
import json
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import argparse

# %%
root_dir = './fruit/pesudo/'
save_path = 'train.json'
images_dir = root_dir + 'images/'
labels_dir = root_dir + 'labels/'
# labels_dir = root_dir + 'labels/'+ 'val/'
# images_dir = root_dir +  'images/'+ 'val/'
random_split = None
split_by_file = None

# %%
def train_test_val_split_random(img_paths,ratio_train=0.8,ratio_test=0.1,ratio_val=0.1):
    # 这里可以修改数据集划分的比例。
    assert int(ratio_train+ratio_test+ratio_val) == 1
    train_img, middle_img = train_test_split(img_paths,test_size=1-ratio_train, random_state=233)
    ratio=ratio_val/(1-ratio_train)
    val_img, test_img  =train_test_split(middle_img,test_size=ratio, random_state=233)
    print("NUMS of train:val:test = {}:{}:{}".format(len(train_img), len(val_img), len(test_img)))
    return train_img, val_img, test_img

def train_test_val_split_by_files(img_paths, root_dir):
    # 根据文件 train.txt, val.txt, test.txt（里面写的都是对应集合的图片名字） 来定义训练集、验证集和测试集
    phases = ['train', 'val', 'test']
    img_split = []
    for p in phases:
        define_path = os.path.join(root_dir, f'{p}.txt')
        print(f'Read {p} dataset definition from {define_path}')
        assert os.path.exists(define_path)
        with open(define_path, 'r') as f:
            img_paths = f.readlines()
            # img_paths = [os.path.split(img_path.strip())[1] for img_path in img_paths]  # NOTE 取消这句备注可以读取绝对地址。
            img_split.append(img_paths)
    return img_split[0], img_split[1], img_split[2]

# %%
def yolo2coco():
    root_path = root_dir
    print("Loading data from ",root_path)

    assert os.path.exists(root_path)
    originLabelsDir = labels_dir                                        
    originImagesDir = images_dir
    with open(os.path.join(root_path, 'classes.txt')) as f:
        classes = f.read().strip().split()
    # images dir name
    indexes = os.listdir(originImagesDir)
    if random_split or split_by_file:
        # 用于保存所有数据的图片信息和标注信息
        train_dataset = {'categories': [], 'annotations': [], 'images': []}
        val_dataset = {'categories': [], 'annotations': [], 'images': []}
        test_dataset = {'categories': [], 'annotations': [], 'images': []}

        # 建立类别标签和数字id的对应关系, 类别id从0开始。
        for i, cls in enumerate(classes, 0):
            train_dataset['categories'].append({'id': i, 'name': cls, 'supercategory': 'mark'})
            val_dataset['categories'].append({'id': i, 'name': cls, 'supercategory': 'mark'})
            test_dataset['categories'].append({'id': i, 'name': cls, 'supercategory': 'mark'})
            
        if random_split:
            print("spliting mode: random split")
            train_img, val_img, test_img = train_test_val_split_random(indexes,0.8,0.1,0.1)
        elif split_by_file:
            print("spliting mode: split by files")
            train_img, val_img, test_img = train_test_val_split_by_files(indexes, root_path)
    else:
        dataset = {'categories': [], 'annotations': [], 'images': []}
        for i, cls in enumerate(classes, 0):
            dataset['categories'].append({'id': i, 'name': cls, 'supercategory': 'mark'})
    
    # 标注的id
    ann_id_cnt = 0
    for k, index in enumerate(tqdm(indexes)):
        # 支持 png jpg 格式的图片。
        txtFile = index.replace('images','txt').replace('.jpg','.txt').replace('.png','.txt')
        # 读取图像的宽和高
        im = cv2.imread(images_dir + index)
        height, width, _ = im.shape
        if random_split or split_by_file:
            # 切换dataset的引用对象，从而划分数据集
                if index in train_img:
                    dataset = train_dataset
                elif index in val_img:
                    dataset = val_dataset
                elif index in test_img:
                    dataset = test_dataset
        # 添加图像的信息
        dataset['images'].append({'file_name': index,
                                    'id': k,
                                    'width': width,
                                    'height': height})
        if not os.path.exists(os.path.join(originLabelsDir, txtFile)):
            # 如没标签，跳过，只保留图片信息。
            continue
        with open(os.path.join(originLabelsDir, txtFile), 'r') as fr:
            labelList = fr.readlines()
            for label in labelList:
                label = label.strip().split()
                x = float(label[1])
                y = float(label[2])
                w = float(label[3])
                h = float(label[4])

                # convert x,y,w,h to x1,y1,x2,y2
                H, W, _ = im.shape
                x1 = (x - w / 2) * W
                y1 = (y - h / 2) * H
                x2 = (x + w / 2) * W
                y2 = (y + h / 2) * H
                # 标签序号从0开始计算, coco2017数据集标号混乱，不管它了。
                cls_id = int(label[0])   
                width = max(0, x2 - x1)
                height = max(0, y2 - y1)
                dataset['annotations'].append({
                    'area': width * height,
                    'bbox': [x1, y1, width, height],
                    'category_id': cls_id,
                    'id': ann_id_cnt,
                    'image_id': k,
                    'iscrowd': 0,
                    # mask, 矩形是从左上角点按顺时针的四个顶点
                    'segmentation': [[x1, y1, x2, y1, x2, y2, x1, y2]]
                })
                ann_id_cnt += 1

    # 保存结果
    folder = os.path.join(root_path, 'annotations')
    if not os.path.exists(folder):
        os.makedirs(folder)
    if random_split or split_by_file:
        for phase in ['train','val','test']:
            json_name = os.path.join(root_path, 'annotations/{}.json'.format(phase))
            with open(json_name, 'w') as f:
                if phase == 'train':
                    json.dump(train_dataset, f)
                elif phase == 'val':
                    json.dump(val_dataset, f)
                elif phase == 'test':
                    json.dump(test_dataset, f)
            print('Save annotation to {}'.format(json_name))
    else:
        json_name = os.path.join(root_path, 'annotations/{}'.format(save_path))
        with open(json_name, 'w') as f:
            json.dump(dataset, f)
            print('Save annotation to {}'.format(json_name))

# %%
yolo2coco()
# Out:
# Loading data from  ./fruit/pesudo/
# 100%|███████████████████████████████████████████████████████████████████████████████| 571/571 [00:04<00:00, 135.54it/s]
# Save annotation to ./fruit/pesudo/annotations/train.json

# %%
import json
json_file = './fruit/train/yolo_dataset/annotations/val.json'
data = json.load(open(json_file, 'r'))
data
# Out:
# {'categories': [{'id': 0, 'name': 'shoot', 'supercategory': 'mark'}],
#  'annotations': [{'area': 24527.999999999996,
#    'bbox': [250.00000000000003, 131.0, 145.99999999999997, 168.0],
#    'category_id': 0,
#    'id': 0,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[250.00000000000003,
#      131.0,
#      396.0,
#      131.0,
#      396.0,
#      299.0,
#      250.00000000000003,
#      299.0]]},
#   {'area': 20961.0,
#    'bbox': [142.0, 238.0, 153.0, 137.0],
#    'category_id': 0,
#    'id': 1,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[142.0, 238.0, 295.0, 238.0, 295.0, 375.0, 142.0, 375.0]]},
#   {'area': 8454.999999999998,
#    'bbox': [67.0, 299.99999999999994, 88.99999999999997, 95.0],
#    'category_id': 0,
#    'id': 2,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[67.0,
#      299.99999999999994,
#      155.99999999999997,
#      299.99999999999994,
#      155.99999999999997,
#      394.99999999999994,
#      67.0,
#      394.99999999999994]]},
#   {'area': 14123.999999999993,
#    'bbox': [247.0, 318.0, 132.0, 106.99999999999994],
#    'category_id': 0,
#    'id': 3,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[247.0,
#      318.0,
#      379.0,
#      318.0,
#      379.0,
#      424.99999999999994,
#      247.0,
#      424.99999999999994]]},
#   {'area': 18070.000000000007,
#    'bbox': [351.99999999999994, 269.0, 130.00000000000006, 139.0],
#    'category_id': 0,
#    'id': 4,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[351.99999999999994,
#      269.0,
#      482.0,
#      269.0,
#      482.0,
#      408.0,
#      351.99999999999994,
#      408.0]]},
#   {'area': 23975.999999999996,
#    'bbox': [117.0, 217.00000000000003, 148.0, 161.99999999999997],
#    'category_id': 0,
#    'id': 5,
#    'image_id': 1,
#    'iscrowd': 0,
#    'segmentation': [[117.0,
#      217.00000000000003,
#      265.0,
#      217.00000000000003,
#      265.0,
#      379.0,
#      117.0,
#      379.0]]},
#   {'area': 29016.0,
#    'bbox': [209.0, 148.0, 156.0, 186.0],
#    'category_id': 0,
#    'id': 6,
#    'image_id': 1,
#    'iscrowd': 0,
#    'segmentation': [[209.0, 148.0, 365.0, 148.0, 365.0, 334.0, 209.0, 334.0]]},
#   {'area': 27714.000000000004,
#    'bbox': [325.0, 211.99999999999997, 186.0, 149.00000000000003],
#    'category_id': 0,
#    'id': 7,
#    'image_id': 2,
#    'iscrowd': 0,
#    'segmentation': [[325.0,
#      211.99999999999997,
#      511.0,
#      211.99999999999997,
#      511.0,
#      361.0,
#      325.0,
#      361.0]]},
#   {'area': 25433.999999999996,
#    'bbox': [6.000000000000002, 197.0, 161.99999999999997, 157.0],
#    'category_id': 0,
#    'id': 8,
#    'image_id': 3,
#    'iscrowd': 0,
#    'segmentation': [[6.000000000000002,
#      197.0,
#      167.99999999999997,
#      197.0,
#      167.99999999999997,
#      354.0,
#      6.000000000000002,
#      354.0]]},
#   {'area': 38745.00000000001,
#    'bbox': [349.0, 133.99999999999997, 189.0, 205.00000000000003],
#    'category_id': 0,
#    'id': 9,
#    'image_id': 3,
#    'iscrowd': 0,
#    'segmentation': [[349.0,
#      133.99999999999997,
#      538.0,
#      133.99999999999997,
#      538.0,
#      339.0,
#      349.0,
#      339.0]]},
#   {'area': 13338.0,
#    'bbox': [483.0, 211.0, 117.0, 114.0],
#    'category_id': 0,
#    'id': 10,
#    'image_id': 3,
#    'iscrowd': 0,
#    'segmentation': [[483.0, 211.0, 600.0, 211.0, 600.0, 325.0, 483.0, 325.0]]},
#   {'area': 19583.999999999993,
#    'bbox': [4.0000000000000036, 275.0, 144.0, 135.99999999999994],
#    'category_id': 0,
#    'id': 11,
#    'image_id': 4,
#    'iscrowd': 0,
#    'segmentation': [[4.0000000000000036,
#      275.0,
#      148.0,
#      275.0,
#      148.0,
#      410.99999999999994,
#      4.0000000000000036,
#      410.99999999999994]]},
#   {'area': 41106.000000000015,
#    'bbox': [48.99999999999997,
#     377.99999999999994,
#     221.00000000000003,
#     186.00000000000006],
#    'category_id': 0,
#    'id': 12,
#    'image_id': 5,
#    'iscrowd': 0,
#    'segmentation': [[48.99999999999997,
#      377.99999999999994,
#      270.0,
#      377.99999999999994,
#      270.0,
#      564.0,
#      48.99999999999997,
#      564.0]]},
#   {'area': 27676.0,
#    'bbox': [382.0, 190.0, 148.0, 187.0],
#    'category_id': 0,
#    'id': 13,
#    'image_id': 5,
#    'iscrowd': 0,
#    'segmentation': [[382.0, 190.0, 530.0, 190.0, 530.0, 377.0, 382.0, 377.0]]},
#   {'area': 33119.99999999999,
#    'bbox': [43.0, 2.000000000000006, 143.99999999999997, 229.99999999999997],
#    'category_id': 0,
#    'id': 14,
#    'image_id': 6,
#    'iscrowd': 0,
#    'segmentation': [[43.0,
#      2.000000000000006,
#      186.99999999999997,
#      2.000000000000006,
#      186.99999999999997,
#      231.99999999999997,
#      43.0,
#      231.99999999999997]]},
#   {'area': 19311.0,
#    'bbox': [11.0, 437.0, 123.0, 157.0],
#    'category_id': 0,
#    'id': 15,
#    'image_id': 6,
#    'iscrowd': 0,
#    'segmentation': [[11.0, 437.0, 134.0, 437.0, 134.0, 594.0, 11.0, 594.0]]},
#   {'area': 31506.00000000001,
#    'bbox': [138.0, 425.99999999999994, 177.0, 178.00000000000006],
#    'category_id': 0,
#    'id': 16,
#    'image_id': 6,
#    'iscrowd': 0,
#    'segmentation': [[138.0,
#      425.99999999999994,
#      315.0,
#      425.99999999999994,
#      315.0,
#      604.0,
#      138.0,
#      604.0]]},
#   {'area': 25487.999999999996,
#    'bbox': [11.999999999999995,
#     54.99999999999998,
#     117.99999999999997,
#     216.00000000000003],
#    'category_id': 0,
#    'id': 17,
#    'image_id': 7,
#    'iscrowd': 0,
#    'segmentation': [[11.999999999999995,
#      54.99999999999998,
#      129.99999999999997,
#      54.99999999999998,
#      129.99999999999997,
#      271.0,
#      11.999999999999995,
#      271.0]]},
#   {'area': 37570.0,
#    'bbox': [132.0, 45.0, 170.0, 221.0],
#    'category_id': 0,
#    'id': 18,
#    'image_id': 7,
#    'iscrowd': 0,
#    'segmentation': [[132.0, 45.0, 302.0, 45.0, 302.0, 266.0, 132.0, 266.0]]},
#   {'area': 15400.000000000004,
#    'bbox': [240.99999999999997, 133.0, 100.00000000000003, 154.0],
#    'category_id': 0,
#    'id': 19,
#    'image_id': 7,
#    'iscrowd': 0,
#    'segmentation': [[240.99999999999997,
#      133.0,
#      341.0,
#      133.0,
#      341.0,
#      287.0,
#      240.99999999999997,
#      287.0]]},
#   {'area': 10591.000000000007,
#    'bbox': [178.99999999999994, 318.99999999999994, 89.00000000000006, 119.0],
#    'category_id': 0,
#    'id': 20,
#    'image_id': 8,
#    'iscrowd': 0,
#    'segmentation': [[178.99999999999994,
#      318.99999999999994,
#      268.0,
#      318.99999999999994,
#      268.0,
#      437.99999999999994,
#      178.99999999999994,
#      437.99999999999994]]},
#   {'area': 4751.9999999999945,
#    'bbox': [95.0, 357.0, 53.99999999999997, 87.99999999999994],
#    'category_id': 0,
#    'id': 21,
#    'image_id': 8,
#    'iscrowd': 0,
#    'segmentation': [[95.0,
#      357.0,
#      148.99999999999997,
#      357.0,
#      148.99999999999997,
#      444.99999999999994,
#      95.0,
#      444.99999999999994]]},
#   {'area': 6344.000000000002,
#    'bbox': [555.9999999999999, 190.99999999999997, 52.0, 122.00000000000003],
#    'category_id': 0,
#    'id': 22,
#    'image_id': 8,
#    'iscrowd': 0,
#    'segmentation': [[555.9999999999999,
#      190.99999999999997,
#      607.9999999999999,
#      190.99999999999997,
#      607.9999999999999,
#      313.0,
#      555.9999999999999,
#      313.0]]},
#   {'area': 47487.999999999985,
#    'bbox': [356.0, 384.99999999999994, 212.0, 223.99999999999994],
#    'category_id': 0,
#    'id': 23,
#    'image_id': 9,
#    'iscrowd': 0,
#    'segmentation': [[356.0,
#      384.99999999999994,
#      568.0,
#      384.99999999999994,
#      568.0,
#      608.9999999999999,
#      356.0,
#      608.9999999999999]]},
#   {'area': 7455.0,
#    'bbox': [325.0, 297.0, 71.0, 105.0],
#    'category_id': 0,
#    'id': 24,
#    'image_id': 10,
#    'iscrowd': 0,
#    'segmentation': [[325.0, 297.0, 396.0, 297.0, 396.0, 402.0, 325.0, 402.0]]},
#   {'area': 14280.0,
#    'bbox': [71.0, 8.000000000000007, 105.0, 136.0],
#    'category_id': 0,
#    'id': 25,
#    'image_id': 11,
#    'iscrowd': 0,
#    'segmentation': [[71.0,
#      8.000000000000007,
#      176.0,
#      8.000000000000007,
#      176.0,
#      144.0,
#      71.0,
#      144.0]]},
#   {'area': 12876.00000000001,
#    'bbox': [351.99999999999994, 318.0, 87.00000000000006, 148.0],
#    'category_id': 0,
#    'id': 26,
#    'image_id': 11,
#    'iscrowd': 0,
#    'segmentation': [[351.99999999999994,
#      318.0,
#      439.0,
#      318.0,
#      439.0,
#      466.0,
#      351.99999999999994,
#      466.0]]},
#   {'area': 17493.000000000007,
#    'bbox': [442.99999999999994, 351.0, 119.00000000000006, 147.0],
#    'category_id': 0,
#    'id': 27,
#    'image_id': 11,
#    'iscrowd': 0,
#    'segmentation': [[442.99999999999994,
#      351.0,
#      562.0,
#      351.0,
#      562.0,
#      498.0,
#      442.99999999999994,
#      498.0]]},
#   {'area': 8689.999999999995,
#    'bbox': [166.0, 374.00000000000006, 110.0, 78.99999999999994],
#    'category_id': 0,
#    'id': 28,
#    'image_id': 11,
#    'iscrowd': 0,
#    'segmentation': [[166.0,
#      374.00000000000006,
#      276.0,
#      374.00000000000006,
#      276.0,
#      453.0,
#      166.0,
#      453.0]]},
#   {'area': 14278.999999999987,
#    'bbox': [472.0, 472.0, 109.0, 130.9999999999999],
#    'category_id': 0,
#    'id': 29,
#    'image_id': 12,
#    'iscrowd': 0,
#    'segmentation': [[472.0,
#      472.0,
#      581.0,
#      472.0,
#      581.0,
#      602.9999999999999,
#      472.0,
#      602.9999999999999]]},
#   {'area': 7410.0,
#    'bbox': [31.000000000000004, 332.99999999999994, 78.0, 95.0],
#    'category_id': 0,
#    'id': 30,
#    'image_id': 12,
#    'iscrowd': 0,
#    'segmentation': [[31.000000000000004,
#      332.99999999999994,
#      109.0,
#      332.99999999999994,
#      109.0,
#      427.99999999999994,
#      31.000000000000004,
#      427.99999999999994]]},
#   {'area': 3564.0,
#    'bbox': [20.999999999999996, 198.0, 54.0, 66.0],
#    'category_id': 0,
#    'id': 31,
#    'image_id': 12,
#    'iscrowd': 0,
#    'segmentation': [[20.999999999999996,
#      198.0,
#      75.0,
#      198.0,
#      75.0,
#      264.0,
#      20.999999999999996,
#      264.0]]},
#   {'area': 3134.999999999997,
#    'bbox': [387.0, 351.0, 57.0, 54.99999999999994],
#    'category_id': 0,
#    'id': 32,
#    'image_id': 12,
#    'iscrowd': 0,
#    'segmentation': [[387.0,
#      351.0,
#      444.0,
#      351.0,
#      444.0,
#      405.99999999999994,
#      387.0,
#      405.99999999999994]]},
#   {'area': 12809.999999999996,
#    'bbox': [467.0, 101.99999999999999, 105.0, 121.99999999999996],
#    'category_id': 0,
#    'id': 33,
#    'image_id': 13,
#    'iscrowd': 0,
#    'segmentation': [[467.0,
#      101.99999999999999,
#      572.0,
#      101.99999999999999,
#      572.0,
#      223.99999999999994,
#      467.0,
#      223.99999999999994]]},
#   {'area': 33088.00000000001,
#    'bbox': [26.000000000000014, 432.99999999999994, 188.0, 176.00000000000006],
#    'category_id': 0,
#    'id': 34,
#    'image_id': 14,
#    'iscrowd': 0,
#    'segmentation': [[26.000000000000014,
#      432.99999999999994,
#      214.0,
#      432.99999999999994,
#      214.0,
#      609.0,
#      26.000000000000014,
#      609.0]]},
#   {'area': 42432.00000000001,
#    'bbox': [225.99999999999997, 417.0, 221.00000000000003, 192.0],
#    'category_id': 0,
#    'id': 35,
#    'image_id': 14,
#    'iscrowd': 0,
#    'segmentation': [[225.99999999999997,
#      417.0,
#      447.0,
#      417.0,
#      447.0,
#      609.0,
#      225.99999999999997,
#      609.0]]},
#   {'area': 35335.0,
#    'bbox': [22.999999999999996, 63.0, 191.0, 185.0],
#    'category_id': 0,
#    'id': 36,
#    'image_id': 15,
#    'iscrowd': 0,
#    'segmentation': [[22.999999999999996,
#      63.0,
#      214.0,
#      63.0,
#      214.0,
#      248.0,
#      22.999999999999996,
#      248.0]]},
#   {'area': 27379.0,
#    'bbox': [69.0, 248.0, 209.0, 131.0],
#    'category_id': 0,
#    'id': 37,
#    'image_id': 15,
#    'iscrowd': 0,
#    'segmentation': [[69.0, 248.0, 278.0, 248.0, 278.0, 379.0, 69.0, 379.0]]},
#   {'area': 42874.999999999985,
#    'bbox': [204.0, 57.99999999999999, 244.99999999999994, 174.99999999999997],
#    'category_id': 0,
#    'id': 38,
#    'image_id': 15,
#    'iscrowd': 0,
#    'segmentation': [[204.0,
#      57.99999999999999,
#      448.99999999999994,
#      57.99999999999999,
#      448.99999999999994,
#      232.99999999999997,
#      204.0,
#      232.99999999999997]]},
#   {'area': 32604.0,
#    'bbox': [140.0, 477.0, 247.0, 132.0],
#    'category_id': 0,
#    'id': 39,
#    'image_id': 16,
#    'iscrowd': 0,
#    'segmentation': [[140.0, 477.0, 387.0, 477.0, 387.0, 609.0, 140.0, 609.0]]},
#   {'area': 39744.0,
#    'bbox': [71.0, 2.000000000000006, 192.0, 207.0],
#    'category_id': 0,
#    'id': 40,
#    'image_id': 16,
#    'iscrowd': 0,
#    'segmentation': [[71.0,
#      2.000000000000006,
#      263.0,
#      2.000000000000006,
#      263.0,
#      209.0,
#      71.0,
#      209.0]]},
#   {'area': 23800.0,
#    'bbox': [67.0, 349.0, 140.0, 170.0],
#    'category_id': 0,
#    'id': 41,
#    'image_id': 17,
#    'iscrowd': 0,
#    'segmentation': [[67.0, 349.0, 207.0, 349.0, 207.0, 519.0, 67.0, 519.0]]},
#   {'area': 43554.0,
#    'bbox': [234.0, 190.0, 183.0, 238.0],
#    'category_id': 0,
#    'id': 42,
#    'image_id': 17,
#    'iscrowd': 0,
#    'segmentation': [[234.0, 190.0, 417.0, 190.0, 417.0, 428.0, 234.0, 428.0]]},
#   {'area': 18966.0,
#    'bbox': [364.0, 306.0, 174.0, 109.0],
#    'category_id': 0,
#    'id': 43,
#    'image_id': 17,
#    'iscrowd': 0,
#    'segmentation': [[364.0, 306.0, 538.0, 306.0, 538.0, 415.0, 364.0, 415.0]]},
#   {'area': 29345.99999999998,
#    'bbox': [100.99999999999999, 314.0, 146.0, 200.9999999999999],
#    'category_id': 0,
#    'id': 44,
#    'image_id': 18,
#    'iscrowd': 0,
#    'segmentation': [[100.99999999999999,
#      314.0,
#      247.0,
#      314.0,
#      247.0,
#      514.9999999999999,
#      100.99999999999999,
#      514.9999999999999]]},
#   {'area': 38080.00000000001,
#    'bbox': [257.0, 252.99999999999997, 170.0, 224.00000000000003],
#    'category_id': 0,
#    'id': 45,
#    'image_id': 18,
#    'iscrowd': 0,
#    'segmentation': [[257.0,
#      252.99999999999997,
#      427.0,
#      252.99999999999997,
#      427.0,
#      477.0,
#      257.0,
#      477.0]]},
#   {'area': 29568.0,
#    'bbox': [171.0, 244.99999999999994, 132.0, 224.0],
#    'category_id': 0,
#    'id': 46,
#    'image_id': 18,
#    'iscrowd': 0,
#    'segmentation': [[171.0,
#      244.99999999999994,
#      303.0,
#      244.99999999999994,
#      303.0,
#      468.99999999999994,
#      171.0,
#      468.99999999999994]]},
#   {'area': 18327.999999999996,
#    'bbox': [195.0, 139.99999999999997, 116.0, 157.99999999999997],
#    'category_id': 0,
#    'id': 47,
#    'image_id': 19,
#    'iscrowd': 0,
#    'segmentation': [[195.0,
#      139.99999999999997,
#      311.0,
#      139.99999999999997,
#      311.0,
#      297.99999999999994,
#      195.0,
#      297.99999999999994]]},
#   {'area': 9269.999999999989,
#    'bbox': [320.0, 493.0, 90.0, 102.99999999999989],
#    'category_id': 0,
#    'id': 48,
#    'image_id': 19,
#    'iscrowd': 0,
#    'segmentation': [[320.0,
#      493.0,
#      410.0,
#      493.0,
#      410.0,
#      595.9999999999999,
#      320.0,
#      595.9999999999999]]},
#   {'area': 16799.999999999985,
#    'bbox': [206.99999999999997, 432.0, 99.99999999999997, 167.9999999999999],
#    'category_id': 0,
#    'id': 49,
#    'image_id': 20,
#    'iscrowd': 0,
#    'segmentation': [[206.99999999999997,
#      432.0,
#      306.99999999999994,
#      432.0,
#      306.99999999999994,
#      599.9999999999999,
#      206.99999999999997,
#      599.9999999999999]]},
#   {'area': 20068.000000000004,
#    'bbox': [3.000000000000001,
#     349.99999999999994,
#     115.99999999999999,
#     173.00000000000006],
#    'category_id': 0,
#    'id': 50,
#    'image_id': 21,
#    'iscrowd': 0,
#    'segmentation': [[3.000000000000001,
#      349.99999999999994,
#      118.99999999999999,
#      349.99999999999994,
#      118.99999999999999,
#      523.0,
#      3.000000000000001,
#      523.0]]},
#   {'area': 22908.000000000007,
#    'bbox': [109.0, 385.99999999999994, 138.0, 166.00000000000006],
#    'category_id': 0,
#    'id': 51,
#    'image_id': 21,
#    'iscrowd': 0,
#    'segmentation': [[109.0,
#      385.99999999999994,
#      247.0,
#      385.99999999999994,
#      247.0,
#      552.0,
#      109.0,
#      552.0]]},
#   {'area': 12725.999999999989,
#    'bbox': [51.99999999999999, 346.0, 101.0, 125.99999999999989],
#    'category_id': 0,
#    'id': 52,
#    'image_id': 22,
#    'iscrowd': 0,
#    'segmentation': [[51.99999999999999,
#      346.0,
#      153.0,
#      346.0,
#      153.0,
#      471.9999999999999,
#      51.99999999999999,
#      471.9999999999999]]},
#   {'area': 13299.000000000002,
#    'bbox': [174.99999999999997, 272.99999999999994, 143.00000000000003, 93.0],
#    'category_id': 0,
#    'id': 53,
#    'image_id': 22,
#    'iscrowd': 0,
#    'segmentation': [[174.99999999999997,
#      272.99999999999994,
#      318.0,
#      272.99999999999994,
#      318.0,
#      365.99999999999994,
#      174.99999999999997,
#      365.99999999999994]]},
#   {'area': 13267.999999999996,
#    'bbox': [249.99999999999997, 339.0, 106.99999999999997, 124.0],
#    'category_id': 0,
#    'id': 54,
#    'image_id': 22,
#    'iscrowd': 0,
#    'segmentation': [[249.99999999999997,
#      339.0,
#      356.99999999999994,
#      339.0,
#      356.99999999999994,
#      463.0,
#      249.99999999999997,
#      463.0]]},
#   {'area': 14267.999999999993,
#    'bbox': [292.99999999999994, 224.0, 123.0, 115.99999999999994],
#    'category_id': 0,
#    'id': 55,
#    'image_id': 22,
#    'iscrowd': 0,
#    'segmentation': [[292.99999999999994,
#      224.0,
#      415.99999999999994,
#      224.0,
#      415.99999999999994,
#      339.99999999999994,
#      292.99999999999994,
#      339.99999999999994]]},
#   {'area': 26712.000000000007,
#    'bbox': [373.99999999999994, 185.0, 168.00000000000006, 159.0],
#    'category_id': 0,
#    'id': 56,
#    'image_id': 22,
#    'iscrowd': 0,
#    'segmentation': [[373.99999999999994,
#      185.0,
#      542.0,
#      185.0,
#      542.0,
#      344.0,
#      373.99999999999994,
#      344.0]]},
#   {'area': 42431.999999999985,
#    'bbox': [48.99999999999999,
#     123.99999999999999,
#     191.99999999999997,
#     220.99999999999994],
#    'category_id': 0,
#    'id': 57,
#    'image_id': 23,
#    'iscrowd': 0,
#    'segmentation': [[48.99999999999999,
#      123.99999999999999,
#      240.99999999999997,
#      123.99999999999999,
#      240.99999999999997,
#      344.99999999999994,
#      48.99999999999999,
#      344.99999999999994]]},
#   {'area': 10590.999999999993,
#    'bbox': [133.0, 413.0, 119.0, 88.99999999999994],
#    'category_id': 0,
#    'id': 58,
#    'image_id': 23,
#    'iscrowd': 0,
#    'segmentation': [[133.0,
#      413.0,
#      252.0,
#      413.0,
#      252.0,
#      501.99999999999994,
#      133.0,
#      501.99999999999994]]},
#   {'area': 14507.999999999998,
#    'bbox': [127.0, 25.99999999999999, 124.0, 116.99999999999999],
#    'category_id': 0,
#    'id': 59,
#    'image_id': 24,
#    'iscrowd': 0,
#    'segmentation': [[127.0,
#      25.99999999999999,
#      251.0,
#      25.99999999999999,
#      251.0,
#      142.99999999999997,
#      127.0,
#      142.99999999999997]]},
#   {'area': 25809.999999999996,
#    'bbox': [199.99999999999997, 185.0, 144.99999999999997, 178.0],
#    'category_id': 0,
#    'id': 60,
#    'image_id': 25,
#    'iscrowd': 0,
#    'segmentation': [[199.99999999999997,
#      185.0,
#      344.99999999999994,
#      185.0,
#      344.99999999999994,
#      363.0,
#      199.99999999999997,
#      363.0]]},
#   {'area': 9118.0,
#    'bbox': [258.99999999999994, 387.0, 97.00000000000006, 93.99999999999994],
#    'category_id': 0,
#    'id': 61,
#    'image_id': 25,
#    'iscrowd': 0,
#    'segmentation': [[258.99999999999994,
#      387.0,
#      356.0,
#      387.0,
#      356.0,
#      480.99999999999994,
#      258.99999999999994,
#      480.99999999999994]]},
#   {'area': 24453.0,
#    'bbox': [261.99999999999994, 83.99999999999999, 171.0, 143.0],
#    'category_id': 0,
#    'id': 62,
#    'image_id': 26,
#    'iscrowd': 0,
#    'segmentation': [[261.99999999999994,
#      83.99999999999999,
#      432.99999999999994,
#      83.99999999999999,
#      432.99999999999994,
#      227.0,
#      261.99999999999994,
#      227.0]]},
#   {'area': 29463.00000000001,
#    'bbox': [220.99999999999997,
#     218.99999999999997,
#     183.00000000000003,
#     161.00000000000003],
#    'category_id': 0,
#    'id': 63,
#    'image_id': 26,
#    'iscrowd': 0,
#    'segmentation': [[220.99999999999997,
#      218.99999999999997,
#      404.0,
#      218.99999999999997,
#      404.0,
#      380.0,
#      220.99999999999997,
#      380.0]]},
#   {'area': 14820.000000000007,
#    'bbox': [456.99999999999994, 131.0, 114.00000000000006, 130.0],
#    'category_id': 0,
#    'id': 64,
#    'image_id': 26,
#    'iscrowd': 0,
#    'segmentation': [[456.99999999999994,
#      131.0,
#      571.0,
#      131.0,
#      571.0,
#      261.0,
#      456.99999999999994,
#      261.0]]},
#   {'area': 28566.0,
#    'bbox': [252.0, 392.0, 138.0, 207.0],
#    'category_id': 0,
#    'id': 65,
#    'image_id': 27,
#    'iscrowd': 0,
#    'segmentation': [[252.0, 392.0, 390.0, 392.0, 390.0, 599.0, 252.0, 599.0]]},
#   {'area': 24674.99999999999,
#    'bbox': [325.0, 411.0, 140.99999999999994, 175.0],
#    'category_id': 0,
#    'id': 66,
#    'image_id': 27,
#    'iscrowd': 0,
#    'segmentation': [[325.0,
#      411.0,
#      465.99999999999994,
#      411.0,
#      465.99999999999994,
#      586.0,
#      325.0,
#      586.0]]},
#   {'area': 13463.999999999995,
#    'bbox': [3.000000000000001, 371.0, 99.0, 135.99999999999994],
#    'category_id': 0,
#    'id': 67,
#    'image_id': 28,
#    'iscrowd': 0,
#    'segmentation': [[3.000000000000001,
#      371.0,
#      102.0,
#      371.0,
#      102.0,
#      506.99999999999994,
#      3.000000000000001,
#      506.99999999999994]]},
#   {'area': 21149.999999999975,
#    'bbox': [261.0, 455.0, 140.99999999999994, 149.9999999999999],
#    'category_id': 0,
#    'id': 68,
#    'image_id': 28,
#    'iscrowd': 0,
#    'segmentation': [[261.0,
#      455.0,
#      401.99999999999994,
#      455.0,
#      401.99999999999994,
#      604.9999999999999,
#      261.0,
#      604.9999999999999]]},
#   {'area': 11117.999999999982,
#    'bbox': [398.0, 503.0, 108.99999999999994, 101.99999999999989],
#    'category_id': 0,
#    'id': 69,
#    'image_id': 28,
#    'iscrowd': 0,
#    'segmentation': [[398.0,
#      503.0,
#      506.99999999999994,
#      503.0,
#      506.99999999999994,
#      604.9999999999999,
#      398.0,
#      604.9999999999999]]},
#   {'area': 23310.000000000007,
#    'bbox': [249.99999999999997, 150.0, 111.00000000000003, 210.0],
#    'category_id': 0,
#    'id': 70,
#    'image_id': 29,
#    'iscrowd': 0,
#    'segmentation': [[249.99999999999997,
#      150.0,
#      361.0,
#      150.0,
#      361.0,
#      360.0,
#      249.99999999999997,
#      360.0]]},
#   {'area': 30954.999999999978,
#    'bbox': [301.0, 118.99999999999999, 150.99999999999994, 204.99999999999994],
#    'category_id': 0,
#    'id': 71,
#    'image_id': 29,
#    'iscrowd': 0,
#    'segmentation': [[301.0,
#      118.99999999999999,
#      451.99999999999994,
#      118.99999999999999,
#      451.99999999999994,
#      323.99999999999994,
#      301.0,
#      323.99999999999994]]},
#   {'area': 47998.000000000015,
#    'bbox': [381.99999999999994, 116.0, 206.00000000000006, 233.0],
#    'category_id': 0,
#    'id': 72,
#    'image_id': 29,
#    'iscrowd': 0,
#    'segmentation': [[381.99999999999994,
#      116.0,
#      588.0,
#      116.0,
#      588.0,
#      349.0,
#      381.99999999999994,
#      349.0]]},
#   {'area': 47359.99999999999,
#    'bbox': [231.00000000000003, 292.0, 184.99999999999997, 256.0],
#    'category_id': 0,
#    'id': 73,
#    'image_id': 30,
#    'iscrowd': 0,
#    'segmentation': [[231.00000000000003,
#      292.0,
#      416.0,
#      292.0,
#      416.0,
#      548.0,
#      231.00000000000003,
#      548.0]]},
#   {'area': 28152.0,
#    'bbox': [450.99999999999994,
#     404.99999999999994,
#     153.00000000000006,
#     183.99999999999994],
#    'category_id': 0,
#    'id': 74,
#    'image_id': 30,
#    'iscrowd': 0,
#    'segmentation': [[450.99999999999994,
#      404.99999999999994,
#      604.0,
#      404.99999999999994,
#      604.0,
#      588.9999999999999,
#      450.99999999999994,
#      588.9999999999999]]},
#   {'area': 15197.00000000001,
#    'bbox': [292.99999999999994, 154.0, 91.00000000000006, 167.0],
#    'category_id': 0,
#    'id': 75,
#    'image_id': 31,
#    'iscrowd': 0,
#    'segmentation': [[292.99999999999994,
#      154.0,
#      384.0,
#      154.0,
#      384.0,
#      321.0,
#      292.99999999999994,
#      321.0]]},
#   {'area': 30407.999999999985,
#    'bbox': [49.00000000000001, 225.00000000000003, 181.0, 167.99999999999991],
#    'category_id': 0,
#    'id': 76,
#    'image_id': 32,
#    'iscrowd': 0,
#    'segmentation': [[49.00000000000001,
#      225.00000000000003,
#      230.0,
#      225.00000000000003,
#      230.0,
#      392.99999999999994,
#      49.00000000000001,
#      392.99999999999994]]},
#   {'area': 17820.0,
#    'bbox': [167.99999999999997, 235.0, 108.00000000000003, 164.99999999999994],
#    'category_id': 0,
#    'id': 77,
#    'image_id': 33,
#    'iscrowd': 0,
#    'segmentation': [[167.99999999999997,
#      235.0,
#      276.0,
#      235.0,
#      276.0,
#      399.99999999999994,
#      167.99999999999997,
#      399.99999999999994]]},
#   {'area': 63195.999999999985,
#    'bbox': [215.0, 66.0, 243.99999999999994, 259.0],
#    'category_id': 0,
#    'id': 78,
#    'image_id': 33,
#    'iscrowd': 0,
#    'segmentation': [[215.0,
#      66.0,
#      458.99999999999994,
#      66.0,
#      458.99999999999994,
#      325.0,
#      215.0,
#      325.0]]},
#   {'area': 24794.99999999999,
#    'bbox': [172.0, 65.99999999999999, 144.99999999999994, 171.0],
#    'category_id': 0,
#    'id': 79,
#    'image_id': 34,
#    'iscrowd': 0,
#    'segmentation': [[172.0,
#      65.99999999999999,
#      316.99999999999994,
#      65.99999999999999,
#      316.99999999999994,
#      237.0,
#      172.0,
#      237.0]]},
#   {'area': 51447.99999999999,
#    'bbox': [247.99999999999997, 335.0, 217.99999999999997, 236.0],
#    'category_id': 0,
#    'id': 80,
#    'image_id': 34,
#    'iscrowd': 0,
#    'segmentation': [[247.99999999999997,
#      335.0,
#      465.99999999999994,
#      335.0,
#      465.99999999999994,
#      571.0,
#      247.99999999999997,
#      571.0]]},
#   {'area': 9255.999999999989,
#    'bbox': [491.0, 448.0, 104.0, 88.99999999999989],
#    'category_id': 0,
#    'id': 81,
#    'image_id': 34,
#    'iscrowd': 0,
#    'segmentation': [[491.0,
#      448.0,
#      595.0,
#      448.0,
#      595.0,
#      536.9999999999999,
#      491.0,
#      536.9999999999999]]},
#   {'area': 42639.999999999985,
#    'bbox': [188.0, 231.99999999999997, 204.99999999999994, 207.99999999999997],
#    'category_id': 0,
#    'id': 82,
#    'image_id': 35,
#    'iscrowd': 0,
#    'segmentation': [[188.0,
#      231.99999999999997,
#      392.99999999999994,
#      231.99999999999997,
#      392.99999999999994,
#      439.99999999999994,
#      188.0,
#      439.99999999999994]]},
#   {'area': 26741.00000000001,
#    'bbox': [380.99999999999994, 232.0, 143.00000000000006, 187.0],
#    'category_id': 0,
#    'id': 83,
#    'image_id': 35,
#    'iscrowd': 0,
#    'segmentation': [[380.99999999999994,
#      232.0,
#      524.0,
#      232.0,
#      524.0,
#      419.0,
#      380.99999999999994,
#      419.0]]},
#   {'area': 8480.000000000004,
#    'bbox': [435.0, 384.99999999999994, 80.0, 106.00000000000006],
#    'category_id': 0,
#    'id': 84,
#    'image_id': 35,
#    'iscrowd': 0,
#    'segmentation': [[435.0,
#      384.99999999999994,
#      515.0,
#      384.99999999999994,
#      515.0,
#      491.0,
#      435.0,
#      491.0]]},
#   {'area': 8216.0,
#    'bbox': [91.0, 56.0, 104.0, 79.0],
#    'category_id': 0,
#    'id': 85,
#    'image_id': 36,
#    'iscrowd': 0,
#    'segmentation': [[91.0, 56.0, 195.0, 56.0, 195.0, 135.0, 91.0, 135.0]]},
#   {'area': 16048.000000000004,
#    'bbox': [231.99999999999997, 316.99999999999994, 136.00000000000003, 118.0],
#    'category_id': 0,
#    'id': 86,
#    'image_id': 36,
#    'iscrowd': 0,
#    'segmentation': [[231.99999999999997,
#      316.99999999999994,
#      368.0,
#      316.99999999999994,
#      368.0,
#      434.99999999999994,
#      231.99999999999997,
#      434.99999999999994]]},
#   {'area': 10395.000000000004,
#    'bbox': [104.0, 306.99999999999994, 77.0, 135.00000000000006],
#    'category_id': 0,
#    'id': 87,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[104.0,
#      306.99999999999994,
#      181.0,
#      306.99999999999994,
#      181.0,
#      442.0,
#      104.0,
#      442.0]]},
#   {'area': 3596.0000000000023,
#    'bbox': [93.99999999999999,
#     442.99999999999994,
#     57.999999999999986,
#     62.00000000000006],
#    'category_id': 0,
#    'id': 88,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[93.99999999999999,
#      442.99999999999994,
#      151.99999999999997,
#      442.99999999999994,
#      151.99999999999997,
#      505.0,
#      93.99999999999999,
#      505.0]]},
#   {'area': 3181.9999999999995,
#    'bbox': [180.99999999999997, 377.0, 43.00000000000003, 73.99999999999994],
#    'category_id': 0,
#    'id': 89,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[180.99999999999997,
#      377.0,
#      224.0,
#      377.0,
#      224.0,
#      450.99999999999994,
#      180.99999999999997,
#      450.99999999999994]]},
#   {'area': 8320.000000000005,
#    'bbox': [216.99999999999994,
#     252.99999999999997,
#     65.00000000000006,
#     127.99999999999997],
#    'category_id': 0,
#    'id': 90,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[216.99999999999994,
#      252.99999999999997,
#      282.0,
#      252.99999999999997,
#      282.0,
#      380.99999999999994,
#      216.99999999999994,
#      380.99999999999994]]},
#   {'area': 4619.999999999998,
#    'bbox': [523.0, 243.99999999999997, 70.0, 65.99999999999997],
#    'category_id': 0,
#    'id': 91,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[523.0,
#      243.99999999999997,
#      593.0,
#      243.99999999999997,
#      593.0,
#      309.99999999999994,
#      523.0,
#      309.99999999999994]]},
#   {'area': 3299.9999999999927,
#    'bbox': [482.0, 197.0, 49.999999999999886, 66.0],
#    'category_id': 0,
#    'id': 92,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[482.0,
#      197.0,
#      531.9999999999999,
#      197.0,
#      531.9999999999999,
#      263.0,
#      482.0,
#      263.0]]},
#   {'area': 1482.0000000000011,
#    'bbox': [456.0, 224.99999999999997, 38.0, 39.00000000000003],
#    'category_id': 0,
#    'id': 93,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[456.0,
#      224.99999999999997,
#      494.0,
#      224.99999999999997,
#      494.0,
#      264.0,
#      456.0,
#      264.0]]},
#   {'area': 1961.0,
#    'bbox': [530.0, 455.99999999999994, 37.0, 53.0],
#    'category_id': 0,
#    'id': 94,
#    'image_id': 37,
#    'iscrowd': 0,
#    'segmentation': [[530.0,
#      455.99999999999994,
#      567.0,
#      455.99999999999994,
#      567.0,
#      508.99999999999994,
#      530.0,
#      508.99999999999994]]},
#   {'area': 7280.0000000000055,
#    'bbox': [261.99999999999994, 337.99999999999994, 70.00000000000006, 104.0],
#    'category_id': 0,
#    'id': 95,
#    'image_id': 38,
#    'iscrowd': 0,
#    'segmentation': [[261.99999999999994,
#      337.99999999999994,
#      332.0,
#      337.99999999999994,
#      332.0,
#      441.99999999999994,
#      261.99999999999994,
#      441.99999999999994]]},
#   {'area': 10374.0,
#    'bbox': [303.0, 256.0, 78.0, 133.0],
#    'category_id': 0,
#    'id': 96,
#    'image_id': 38,
#    'iscrowd': 0,
#    'segmentation': [[303.0, 256.0, 381.0, 256.0, 381.0, 389.0, 303.0, 389.0]]},
#   {'area': 5162.0000000000055,
#    'bbox': [356.99999999999994, 300.0, 58.00000000000006, 89.0],
#    'category_id': 0,
#    'id': 97,
#    'image_id': 38,
#    'iscrowd': 0,
#    'segmentation': [[356.99999999999994,
#      300.0,
#      415.0,
#      300.0,
#      415.0,
#      389.0,
#      356.99999999999994,
#      389.0]]},
#   {'area': 37784.99999999999,
#    'bbox': [226.99999999999997, 313.0, 229.00000000000003, 164.99999999999994],
#    'category_id': 0,
#    'id': 98,
#    'image_id': 39,
#    'iscrowd': 0,
#    'segmentation': [[226.99999999999997,
#      313.0,
#      456.0,
#      313.0,
#      456.0,
#      477.99999999999994,
#      226.99999999999997,
#      477.99999999999994]]},
#   {'area': 13192.0,
#    'bbox': [11.000000000000009, 102.0, 136.0, 97.0],
#    'category_id': 0,
#    'id': 99,
#    'image_id': 39,
#    'iscrowd': 0,
#    'segmentation': [[11.000000000000009,
#      102.0,
#      147.0,
#      102.0,
#      147.0,
#      199.0,
#      11.000000000000009,
#      199.0]]},
#   {'area': 10836.000000000004,
#    'bbox': [111.99999999999997, 160.0, 86.00000000000003, 126.0],
#    'category_id': 0,
#    'id': 100,
#    'image_id': 39,
#    'iscrowd': 0,
#    'segmentation': [[111.99999999999997,
#      160.0,
#      198.0,
#      160.0,
#      198.0,
#      286.0,
#      111.99999999999997,
#      286.0]]},
#   {'area': 11609.999999999996,
#    'bbox': [181.99999999999997, 249.0, 89.99999999999997, 129.0],
#    'category_id': 0,
#    'id': 101,
#    'image_id': 39,
#    'iscrowd': 0,
#    'segmentation': [[181.99999999999997,
#      249.0,
#      271.99999999999994,
#      249.0,
#      271.99999999999994,
#      378.0,
#      181.99999999999997,
#      378.0]]},
#   {'area': 6805.999999999999,
#    'bbox': [1.9999999999999978, 6.9999999999999964, 81.99999999999999, 83.0],
#    'category_id': 0,
#    'id': 102,
#    'image_id': 39,
#    'iscrowd': 0,
#    'segmentation': [[1.9999999999999978,
#      6.9999999999999964,
#      83.99999999999999,
#      6.9999999999999964,
#      83.99999999999999,
#      90.0,
#      1.9999999999999978,
#      90.0]]},
#   {'area': 37467.0,
#    'bbox': [402.0, 270.99999999999994, 207.0, 181.0],
#    'category_id': 0,
#    'id': 103,
#    'image_id': 40,
#    'iscrowd': 0,
#    'segmentation': [[402.0,
#      270.99999999999994,
#      609.0,
#      270.99999999999994,
#      609.0,
#      451.99999999999994,
#      402.0,
#      451.99999999999994]]},
#   {'area': 8307.0,
#    'bbox': [354.99999999999994, 298.0, 71.0, 117.0],
#    'category_id': 0,
#    'id': 104,
#    'image_id': 41,
#    'iscrowd': 0,
#    'segmentation': [[354.99999999999994,
#      298.0,
#      425.99999999999994,
#      298.0,
#      425.99999999999994,
#      415.0,
#      354.99999999999994,
#      415.0]]},
#   {'area': 11542.999999999989,
#    'bbox': [441.0, 180.99999999999997, 96.99999999999989, 119.00000000000003],
#    'category_id': 0,
#    'id': 105,
#    'image_id': 41,
#    'iscrowd': 0,
#    'segmentation': [[441.0,
#      180.99999999999997,
#      537.9999999999999,
#      180.99999999999997,
#      537.9999999999999,
#      300.0,
#      441.0,
#      300.0]]},
#   {'area': 9594.0,
#    'bbox': [101.0, 254.99999999999994, 78.0, 123.0],
#    'category_id': 0,
#    'id': 106,
#    'image_id': 41,
#    'iscrowd': 0,
#    'segmentation': [[101.0,
#      254.99999999999994,
#      179.0,
#      254.99999999999994,
#      179.0,
#      377.99999999999994,
#      101.0,
#      377.99999999999994]]},
#   {'area': 13500.000000000018,
#    'bbox': [496.99999999999994,
#     471.9999999999999,
#     100.00000000000006,
#     135.0000000000001],
#    'category_id': 0,
#    'id': 107,
#    'image_id': 41,
#    'iscrowd': 0,
#    'segmentation': [[496.99999999999994,
#      471.9999999999999,
#      597.0,
#      471.9999999999999,
#      597.0,
#      607.0,
#      496.99999999999994,
#      607.0]]},
#   {'area': 12464.000000000002,
#    'bbox': [8.0, 156.99999999999997, 82.0, 152.00000000000003],
#    'category_id': 0,
#    'id': 108,
#    'image_id': 42,
#    'iscrowd': 0,
#    'segmentation': [[8.0,
#      156.99999999999997,
#      90.0,
#      156.99999999999997,
#      90.0,
#      309.0,
#      8.0,
#      309.0]]},
#   {'area': 2772.999999999998,
#    'bbox': [138.0, 225.99999999999997, 59.0, 46.99999999999997],
#    'category_id': 0,
#    'id': 109,
#    'image_id': 42,
#    'iscrowd': 0,
#    'segmentation': [[138.0,
#      225.99999999999997,
#      197.0,
#      225.99999999999997,
#      197.0,
#      272.99999999999994,
#      138.0,
#      272.99999999999994]]},
#   {'area': 2178.0,
#    'bbox': [104.0, 214.0, 33.0, 66.0],
#    'category_id': 0,
#    'id': 110,
#    'image_id': 42,
#    'iscrowd': 0,
#    'segmentation': [[104.0, 214.0, 137.0, 214.0, 137.0, 280.0, 104.0, 280.0]]},
#   {'area': 35422.0,
#    'bbox': [163.0, 89.0, 199.0, 178.0],
#    'category_id': 0,
#    'id': 111,
#    'image_id': 43,
#    'iscrowd': 0,
#    'segmentation': [[163.0, 89.0, 362.0, 89.0, 362.0, 267.0, 163.0, 267.0]]},
#   {'area': 33534.0,
#    'bbox': [242.99999999999994, 4.000000000000012, 162.0, 207.0],
#    'category_id': 0,
#    'id': 112,
#    'image_id': 43,
#    'iscrowd': 0,
#    'segmentation': [[242.99999999999994,
#      4.000000000000012,
#      404.99999999999994,
#      4.000000000000012,
#      404.99999999999994,
#      211.0,
#      242.99999999999994,
#      211.0]]},
#   {'area': 12407.999999999995,
#    'bbox': [52.99999999999999, 106.00000000000001, 94.0, 131.99999999999994],
#    'category_id': 0,
#    'id': 113,
#    'image_id': 44,
#    'iscrowd': 0,
#    'segmentation': [[52.99999999999999,
#      106.00000000000001,
#      147.0,
#      106.00000000000001,
#      147.0,
#      237.99999999999997,
#      52.99999999999999,
#      237.99999999999997]]},
#   {'area': 6480.0,
#    'bbox': [128.0, 133.0, 72.0, 90.0],
#    'category_id': 0,
#    'id': 114,
#    'image_id': 44,
#    'iscrowd': 0,
#    'segmentation': [[128.0, 133.0, 200.0, 133.0, 200.0, 223.0, 128.0, 223.0]]},
#   {'area': 4879.999999999995,
#    'bbox': [417.0, 1.9999999999999978, 60.99999999999994, 80.0],
#    'category_id': 0,
#    'id': 115,
#    'image_id': 44,
#    'iscrowd': 0,
#    'segmentation': [[417.0,
#      1.9999999999999978,
#      477.99999999999994,
#      1.9999999999999978,
#      477.99999999999994,
#      82.0,
#      417.0,
#      82.0]]},
#   {'area': 7177.999999999997,
#    'bbox': [234.99999999999997, 202.0, 73.99999999999997, 97.0],
#    'category_id': 0,
#    'id': 116,
#    'image_id': 44,
#    'iscrowd': 0,
#    'segmentation': [[234.99999999999997,
#      202.0,
#      308.99999999999994,
#      202.0,
#      308.99999999999994,
#      299.0,
#      234.99999999999997,
#      299.0]]},
#   {'area': 4760.000000000001,
#    'bbox': [487.0, 78.99999999999999, 70.0, 68.00000000000001],
#    'category_id': 0,
#    'id': 117,
#    'image_id': 44,
#    'iscrowd': 0,
#    'segmentation': [[487.0,
#      78.99999999999999,
#      557.0,
#      78.99999999999999,
#      557.0,
#      147.0,
#      487.0,
#      147.0]]},
#   {'area': 5776.000000000001,
#    'bbox': [121.99999999999999, 266.99999999999994, 76.00000000000001, 76.0],
#    'category_id': 0,
#    'id': 118,
#    'image_id': 45,
#    'iscrowd': 0,
#    'segmentation': [[121.99999999999999,
#      266.99999999999994,
#      198.0,
#      266.99999999999994,
#      198.0,
#      342.99999999999994,
#      121.99999999999999,
#      342.99999999999994]]},
#   {'area': 1988.9999999999964,
#    'bbox': [214.0, 266.0, 38.99999999999997, 50.99999999999994],
#    'category_id': 0,
#    'id': 119,
#    'image_id': 45,
#    'iscrowd': 0,
#    'segmentation': [[214.0,
#      266.0,
#      252.99999999999997,
#      266.0,
#      252.99999999999997,
#      316.99999999999994,
#      214.0,
#      316.99999999999994]]},
#   {'area': 5264.999999999994,
#    'bbox': [306.0, 251.99999999999997, 64.99999999999994, 80.99999999999997],
#    'category_id': 0,
#    'id': 120,
#    'image_id': 45,
#    'iscrowd': 0,
#    'segmentation': [[306.0,
#      251.99999999999997,
#      370.99999999999994,
#      251.99999999999997,
#      370.99999999999994,
#      332.99999999999994,
#      306.0,
#      332.99999999999994]]},
#   {'area': 5870.999999999996,
#    'bbox': [382.99999999999994, 268.0, 57.0, 102.99999999999994],
#    'category_id': 0,
#    'id': 121,
#    'image_id': 45,
#    'iscrowd': 0,
#    'segmentation': [[382.99999999999994,
#      268.0,
#      439.99999999999994,
#      268.0,
#      439.99999999999994,
#      370.99999999999994,
#      382.99999999999994,
#      370.99999999999994]]},
#   {'area': 5063.0,
#    'bbox': [531.0, 241.0, 61.0, 83.0],
#    'category_id': 0,
#    'id': 122,
#    'image_id': 45,
#    'iscrowd': 0,
#    'segmentation': [[531.0, 241.0, 592.0, 241.0, 592.0, 324.0, 531.0, 324.0]]},
#   {'area': 8023.0,
#    'bbox': [363.99999999999994, 202.0, 71.0, 113.0],
#    'category_id': 0,
#    'id': 123,
#    'image_id': 45,
#    'iscrowd': 0,
#    'segmentation': [[363.99999999999994,
#      202.0,
#      434.99999999999994,
#      202.0,
#      434.99999999999994,
#      315.0,
#      363.99999999999994,
#      315.0]]},
#   {'area': 28674.000000000004,
#    'bbox': [28.000000000000004, 219.99999999999997, 162.0, 177.00000000000003],
#    'category_id': 0,
#    'id': 124,
#    'image_id': 46,
#    'iscrowd': 0,
#    'segmentation': [[28.000000000000004,
#      219.99999999999997,
#      190.0,
#      219.99999999999997,
#      190.0,
#      397.0,
#      28.000000000000004,
#      397.0]]},
#   {'area': 15593.999999999993,
#    'bbox': [248.00000000000003, 49.0, 112.99999999999997, 137.99999999999997],
#    'category_id': 0,
#    'id': 125,
#    'image_id': 46,
#    'iscrowd': 0,
#    'segmentation': [[248.00000000000003,
#      49.0,
#      361.0,
#      49.0,
#      361.0,
#      186.99999999999997,
#      248.00000000000003,
#      186.99999999999997]]},
#   {'area': 18874.999999999993,
#    'bbox': [228.0, 254.0, 125.0, 150.99999999999994],
#    'category_id': 0,
#    'id': 126,
#    'image_id': 46,
#    'iscrowd': 0,
#    'segmentation': [[228.0,
#      254.0,
#      353.0,
#      254.0,
#      353.0,
#      404.99999999999994,
#      228.0,
#      404.99999999999994]]},
#   {'area': 36126.000000000015,
#    'bbox': [373.99999999999994,
#     174.99999999999997,
#     162.00000000000006,
#     223.00000000000003],
#    'category_id': 0,
#    'id': 127,
#    'image_id': 46,
#    'iscrowd': 0,
#    'segmentation': [[373.99999999999994,
#      174.99999999999997,
#      536.0,
#      174.99999999999997,
#      536.0,
#      398.0,
#      373.99999999999994,
#      398.0]]},
#   {'area': 17534.999999999996,
#    'bbox': [211.99999999999997, 105.99999999999999, 104.99999999999997, 167.0],
#    'category_id': 0,
#    'id': 128,
#    'image_id': 47,
#    'iscrowd': 0,
#    'segmentation': [[211.99999999999997,
#      105.99999999999999,
#      316.99999999999994,
#      105.99999999999999,
#      316.99999999999994,
#      273.0,
#      211.99999999999997,
#      273.0]]},
#   {'area': 15982.0,
#    'bbox': [300.0, 96.99999999999999, 122.0, 131.0],
#    'category_id': 0,
#    'id': 129,
#    'image_id': 47,
#    'iscrowd': 0,
#    'segmentation': [[300.0,
#      96.99999999999999,
#      422.0,
#      96.99999999999999,
#      422.0,
#      228.0,
#      300.0,
#      228.0]]},
#   {'area': 6943.999999999987,
#    'bbox': [547.0, 277.99999999999994, 61.999999999999886, 112.0],
#    'category_id': 0,
#    'id': 130,
#    'image_id': 48,
#    'iscrowd': 0,
#    'segmentation': [[547.0,
#      277.99999999999994,
#      608.9999999999999,
#      277.99999999999994,
#      608.9999999999999,
#      389.99999999999994,
#      547.0,
#      389.99999999999994]]},
#   {'area': 4212.000000000003,
#    'bbox': [450.99999999999994, 141.0, 54.00000000000006, 77.99999999999997],
#    'category_id': 0,
#    'id': 131,
#    'image_id': 48,
#    'iscrowd': 0,
#    'segmentation': [[450.99999999999994,
#      141.0,
#      505.0,
#      141.0,
#      505.0,
#      218.99999999999997,
#      450.99999999999994,
#      218.99999999999997]]},
#   {'area': 12609.999999999995,
#    'bbox': [218.0, 240.0, 129.99999999999994, 97.0],
#    'category_id': 0,
#    'id': 132,
#    'image_id': 48,
#    'iscrowd': 0,
#    'segmentation': [[218.0,
#      240.0,
#      347.99999999999994,
#      240.0,
#      347.99999999999994,
#      337.0,
#      218.0,
#      337.0]]},
#   {'area': 9918.0,
#    'bbox': [1.9999999999999978, 134.0, 87.0, 114.0],
#    'category_id': 0,
#    'id': 133,
#    'image_id': 48,
#    'iscrowd': 0,
#    'segmentation': [[1.9999999999999978,
#      134.0,
#      89.0,
#      134.0,
#      89.0,
#      248.0,
#      1.9999999999999978,
#      248.0]]},
#   {'area': 30246.999999999993,
#    'bbox': [380.99999999999994, 396.0, 202.99999999999994, 149.0],
#    'category_id': 0,
#    'id': 134,
#    'image_id': 48,
#    'iscrowd': 0,
#    'segmentation': [[380.99999999999994,
#      396.0,
#      583.9999999999999,
#      396.0,
#      583.9999999999999,
#      545.0,
#      380.99999999999994,
#      545.0]]},
#   {'area': 41796.000000000015,
#    'bbox': [439.99999999999994, 81.0, 162.00000000000006, 258.0],
#    'category_id': 0,
#    'id': 135,
#    'image_id': 49,
#    'iscrowd': 0,
#    'segmentation': [[439.99999999999994,
#      81.0,
#      602.0,
#      81.0,
#      602.0,
#      339.0,
#      439.99999999999994,
#      339.0]]},
#   {'area': 27488.999999999993,
#    'bbox': [48.0, 199.0, 147.0, 186.99999999999994],
#    'category_id': 0,
#    'id': 136,
#    'image_id': 50,
#    'iscrowd': 0,
#    'segmentation': [[48.0,
#      199.0,
#      195.0,
#      199.0,
#      195.0,
#      385.99999999999994,
#      48.0,
#      385.99999999999994]]},
#   {'area': 18666.000000000007,
#    'bbox': [132.0, 427.99999999999994, 122.0, 153.00000000000006],
#    'category_id': 0,
#    'id': 137,
#    'image_id': 50,
#    'iscrowd': 0,
#    'segmentation': [[132.0,
#      427.99999999999994,
#      254.0,
#      427.99999999999994,
#      254.0,
#      581.0,
#      132.0,
#      581.0]]},
#   {'area': 37411.0,
#    'bbox': [287.0, 344.0, 209.0, 179.0],
#    'category_id': 0,
#    'id': 138,
#    'image_id': 50,
#    'iscrowd': 0,
#    'segmentation': [[287.0, 344.0, 496.0, 344.0, 496.0, 523.0, 287.0, 523.0]]},
#   {'area': 12534.999999999996,
#    'bbox': [29.999999999999993, 38.99999999999999, 108.99999999999997, 115.0],
#    'category_id': 0,
#    'id': 139,
#    'image_id': 51,
#    'iscrowd': 0,
#    'segmentation': [[29.999999999999993,
#      38.99999999999999,
#      138.99999999999997,
#      38.99999999999999,
#      138.99999999999997,
#      154.0,
#      29.999999999999993,
#      154.0]]},
#   {'area': 21149.99999999999,
#    'bbox': [341.0, 188.99999999999997, 149.9999999999999, 141.00000000000003],
#    'category_id': 0,
#    'id': 140,
#    'image_id': 51,
#    'iscrowd': 0,
#    'segmentation': [[341.0,
#      188.99999999999997,
#      490.9999999999999,
#      188.99999999999997,
#      490.9999999999999,
#      330.0,
#      341.0,
#      330.0]]},
#   {'area': 14976.00000000001,
#    'bbox': [363.0, 290.99999999999994, 156.0, 96.00000000000006],
#    'category_id': 0,
#    'id': 141,
#    'image_id': 51,
#    'iscrowd': 0,
#    'segmentation': [[363.0,
#      290.99999999999994,
#      519.0,
#      290.99999999999994,
#      519.0,
#      387.0,
#      363.0,
#      387.0]]},
#   {'area': 14625.000000000007,
#    'bbox': [401.99999999999994, 404.0, 125.00000000000006, 117.0],
#    'category_id': 0,
#    'id': 142,
#    'image_id': 51,
#    'iscrowd': 0,
#    'segmentation': [[401.99999999999994,
#      404.0,
#      527.0,
#      404.0,
#      527.0,
#      521.0,
#      401.99999999999994,
#      521.0]]},
#   {'area': 7951.999999999992,
#    'bbox': [356.99999999999994, 467.0, 71.0, 111.99999999999989],
#    'category_id': 0,
#    'id': 143,
#    'image_id': 52,
#    'iscrowd': 0,
#    'segmentation': [[356.99999999999994,
#      467.0,
#      427.99999999999994,
#      467.0,
#      427.99999999999994,
#      578.9999999999999,
#      356.99999999999994,
#      578.9999999999999]]},
#   {'area': 9710.999999999996,
#    'bbox': [347.0, 105.99999999999997, 82.99999999999994, 117.00000000000003],
#    'category_id': 0,
#    'id': 144,
#    'image_id': 53,
#    'iscrowd': 0,
#    'segmentation': [[347.0,
#      105.99999999999997,
#      429.99999999999994,
#      105.99999999999997,
#      429.99999999999994,
#      223.0,
#      347.0,
#      223.0]]},
#   {'area': 8509.999999999996,
#    'bbox': [374.00000000000006,
#     219.99999999999997,
#     73.99999999999994,
#     115.00000000000003],
#    'category_id': 0,
#    'id': 145,
#    'image_id': 53,
#    'iscrowd': 0,
#    'segmentation': [[374.00000000000006,
#      219.99999999999997,
#      448.0,
#      219.99999999999997,
#      448.0,
#      335.0,
#      374.00000000000006,
#      335.0]]},
#   {'area': 20639.999999999996,
#    'bbox': [193.00000000000003, 80.0, 128.99999999999997, 160.0],
#    'category_id': 0,
#    'id': 146,
#    'image_id': 54,
#    'iscrowd': 0,
#    'segmentation': [[193.00000000000003,
#      80.0,
#      322.0,
#      80.0,
#      322.0,
#      240.0,
#      193.00000000000003,
#      240.0]]},
#   {'area': 13419.999999999995,
#    'bbox': [360.99999999999994, 320.0, 110.0, 121.99999999999994],
#    'category_id': 0,
#    'id': 147,
#    'image_id': 55,
#    'iscrowd': 0,
#    'segmentation': [[360.99999999999994,
#      320.0,
#      470.99999999999994,
#      320.0,
#      470.99999999999994,
#      441.99999999999994,
#      360.99999999999994,
#      441.99999999999994]]},
#   {'area': 15112.999999999993,
#    'bbox': [468.99999999999994, 285.99999999999994, 126.99999999999994, 119.0],
#    'category_id': 0,
#    'id': 148,
#    'image_id': 55,
#    'iscrowd': 0,
#    'segmentation': [[468.99999999999994,
#      285.99999999999994,
#      595.9999999999999,
#      285.99999999999994,
#      595.9999999999999,
#      404.99999999999994,
#      468.99999999999994,
#      404.99999999999994]]},
#   {'area': 8136.999999999992,
#    'bbox': [224.00000000000003, 307.0, 102.99999999999997, 78.99999999999994],
#    'category_id': 0,
#    'id': 149,
#    'image_id': 55,
#    'iscrowd': 0,
#    'segmentation': [[224.00000000000003,
#      307.0,
#      327.0,
#      307.0,
#      327.0,
#      385.99999999999994,
#      224.00000000000003,
#      385.99999999999994]]},
#   {'area': 5016.0,
#    'bbox': [389.99999999999994, 264.0, 57.0, 88.0],
#    'category_id': 0,
#    'id': 150,
#    'image_id': 56,
#    'iscrowd': 0,
#    'segmentation': [[389.99999999999994,
#      264.0,
#      446.99999999999994,
#      264.0,
#      446.99999999999994,
#      352.0,
#      389.99999999999994,
#      352.0]]},
#   {'area': 11717.999999999993,
#    'bbox': [424.00000000000006, 118.99999999999997, 92.99999999999994, 126.0],
#    'category_id': 0,
#    'id': 151,
#    'image_id': 56,
#    'iscrowd': 0,
#    'segmentation': [[424.00000000000006,
#      118.99999999999997,
#      517.0,
#      118.99999999999997,
#      517.0,
#      244.99999999999997,
#      424.00000000000006,
#      244.99999999999997]]},
#   {'area': 16905.00000000001,
#    'bbox': [461.99999999999994,
#     247.99999999999997,
#     147.00000000000006,
#     115.00000000000003],
#    'category_id': 0,
#    'id': 152,
#    'image_id': 56,
#    'iscrowd': 0,
#    'segmentation': [[461.99999999999994,
#      247.99999999999997,
#      609.0,
#      247.99999999999997,
#      609.0,
#      363.0,
#      461.99999999999994,
#      363.0]]},
#   {'area': 8370.0,
#    'bbox': [12.000000000000004, 387.99999999999994, 93.0, 90.0],
#    'category_id': 0,
#    'id': 153,
#    'image_id': 56,
#    'iscrowd': 0,
#    'segmentation': [[12.000000000000004,
#      387.99999999999994,
#      105.0,
#      387.99999999999994,
#      105.0,
#      477.99999999999994,
#      12.000000000000004,
#      477.99999999999994]]},
#   {'area': 30186.000000000007,
#    'bbox': [427.99999999999994, 171.0, 129.00000000000006, 233.99999999999994],
#    'category_id': 0,
#    'id': 154,
#    'image_id': 57,
#    'iscrowd': 0,
#    'segmentation': [[427.99999999999994,
#      171.0,
#      557.0,
#      171.0,
#      557.0,
#      404.99999999999994,
#      427.99999999999994,
#      404.99999999999994]]},
#   {'area': 19838.0,
#    'bbox': [339.0, 358.0, 91.0, 218.0],
#    'category_id': 0,
#    'id': 155,
#    'image_id': 57,
#    'iscrowd': 0,
#    'segmentation': [[339.0, 358.0, 430.0, 358.0, 430.0, 576.0, 339.0, 576.0]]},
#   {'area': 14832.99999999998,
#    'bbox': [245.0, 413.0, 90.99999999999994, 162.9999999999999],
#    'category_id': 0,
#    'id': 156,
#    'image_id': 57,
#    'iscrowd': 0,
#    'segmentation': [[245.0,
#      413.0,
#      335.99999999999994,
#      413.0,
#      335.99999999999994,
#      575.9999999999999,
#      245.0,
#      575.9999999999999]]},
#   {'area': 6006.0,
#    'bbox': [223.0, 299.0, 66.0, 91.0],
#    'category_id': 0,
#    'id': 157,
#    'image_id': 57,
#    'iscrowd': 0,
#    'segmentation': [[223.0, 299.0, 289.0, 299.0, 289.0, 390.0, 223.0, 390.0]]},
#   {'area': 5256.000000000005,
#    'bbox': [150.0, 368.99999999999994, 73.0, 72.00000000000006],
#    'category_id': 0,
#    'id': 158,
#    'image_id': 57,
#    'iscrowd': 0,
#    'segmentation': [[150.0,
#      368.99999999999994,
#      223.0,
#      368.99999999999994,
#      223.0,
#      441.0,
#      150.0,
#      441.0]]},
#   {'area': 8644.999999999985,
#    'bbox': [543.0, 285.99999999999994, 64.99999999999989, 133.0],
#    'category_id': 0,
#    'id': 159,
#    'image_id': 57,
#    'iscrowd': 0,
#    'segmentation': [[543.0,
#      285.99999999999994,
#      607.9999999999999,
#      285.99999999999994,
#      607.9999999999999,
#      418.99999999999994,
#      543.0,
#      418.99999999999994]]},
#   {'area': 38293.00000000001,
#    'bbox': [179.0, 285.99999999999994, 149.0, 257.00000000000006],
#    'category_id': 0,
#    'id': 160,
#    'image_id': 58,
#    'iscrowd': 0,
#    'segmentation': [[179.0,
#      285.99999999999994,
#      328.0,
#      285.99999999999994,
#      328.0,
#      543.0,
#      179.0,
#      543.0]]},
#   {'area': 36952.00000000002,
#    'bbox': [309.99999999999994,
#     240.99999999999997,
#     149.00000000000006,
#     248.00000000000003],
#    'category_id': 0,
#    'id': 161,
#    'image_id': 58,
#    'iscrowd': 0,
#    'segmentation': [[309.99999999999994,
#      240.99999999999997,
#      459.0,
#      240.99999999999997,
#      459.0,
#      489.0,
#      309.99999999999994,
#      489.0]]},
#   {'area': 44492.0,
#    'bbox': [200.99999999999997,
#     2.000000000000006,
#     196.00000000000003,
#     226.99999999999997],
#    'category_id': 0,
#    'id': 162,
#    'image_id': 59,
#    'iscrowd': 0,
#    'segmentation': [[200.99999999999997,
#      2.000000000000006,
#      397.0,
#      2.000000000000006,
#      397.0,
#      228.99999999999997,
#      200.99999999999997,
#      228.99999999999997]]},
#   {'area': 28196.0,
#    'bbox': [8.0, 28.000000000000004, 133.0, 212.0],
#    'category_id': 0,
#    'id': 163,
#    'image_id': 59,
#    'iscrowd': 0,
#    'segmentation': [[8.0,
#      28.000000000000004,
#      141.0,
#      28.000000000000004,
#      141.0,
#      240.0,
#      8.0,
#      240.0]]},
#   {'area': 36719.99999999999,
#    'bbox': [167.99999999999997, 226.0, 179.99999999999997, 204.0],
#    'category_id': 0,
#    'id': 164,
#    'image_id': 60,
#    'iscrowd': 0,
#    'segmentation': [[167.99999999999997,
#      226.0,
#      347.99999999999994,
#      226.0,
#      347.99999999999994,
#      430.0,
#      167.99999999999997,
#      430.0]]},
#   {'area': 17780.0,
#    'bbox': [145.0, 366.0, 140.0, 127.0],
#    'category_id': 0,
#    'id': 165,
#    'image_id': 60,
#    'iscrowd': 0,
#    'segmentation': [[145.0, 366.0, 285.0, 366.0, 285.0, 493.0, 145.0, 493.0]]},
#   {'area': 26070.0,
#    'bbox': [378.0, 370.0, 165.0, 158.0],
#    'category_id': 0,
#    'id': 166,
#    'image_id': 60,
#    'iscrowd': 0,
#    'segmentation': [[378.0, 370.0, 543.0, 370.0, 543.0, 528.0, 378.0, 528.0]]},
#   {'area': 16951.99999999999,
#    'bbox': [120.0, 484.99999999999994, 163.0, 103.99999999999994],
#    'category_id': 0,
#    'id': 167,
#    'image_id': 60,
#    'iscrowd': 0,
#    'segmentation': [[120.0,
#      484.99999999999994,
#      283.0,
#      484.99999999999994,
#      283.0,
#      588.9999999999999,
#      120.0,
#      588.9999999999999]]},
#   {'area': 10709.999999999996,
#    'bbox': [129.0, 256.99999999999994, 89.99999999999997, 119.0],
#    'category_id': 0,
#    'id': 168,
#    'image_id': 61,
#    'iscrowd': 0,
#    'segmentation': [[129.0,
#      256.99999999999994,
#      218.99999999999997,
#      256.99999999999994,
#      218.99999999999997,
#      375.99999999999994,
#      129.0,
#      375.99999999999994]]},
#   {'area': 6720.0,
#    'bbox': [218.0, 287.0, 70.0, 96.0],
#    'category_id': 0,
#    'id': 169,
#    'image_id': 61,
#    'iscrowd': 0,
#    'segmentation': [[218.0,
#      287.0,
#      288.0,
#      287.0,
#      288.0,
#      383.0,
#      218.0,
#      383.0]]}],
#  'images': [{'file_name': 'shoot631_5.jpg',
#    'id': 0,
#    'width': 608,
#    'height': 608},
#   {'file_name': 'shoot632_5.jpg', 'id': 1, 'width': 608, 'height': 608},
#   {'file_name': 'shoot634_2.jpg', 'id': 2, 'width': 608, 'height': 608},
#   {'file_name': 'shoot634_5.jpg', 'id': 3, 'width': 608, 'height': 608},
#   {'file_name': 'shoot634_8.jpg', 'id': 4, 'width': 608, 'height': 608},
#   {'file_name': 'shoot635_5.jpg', 'id': 5, 'width': 608, 'height': 608},
#   {'file_name': 'shoot636_5.jpg', 'id': 6, 'width': 608, 'height': 608},
#   {'file_name': 'shoot636_6.jpg', 'id': 7, 'width': 608, 'height': 608},
#   {'file_name': 'shoot637_5.jpg', 'id': 8, 'width': 608, 'height': 608},
#   {'file_name': 'shoot637_9.jpg', 'id': 9, 'width': 608, 'height': 608},
#   {'file_name': 'shoot638_8.jpg', 'id': 10, 'width': 608, 'height': 608},
#   {'file_name': 'shoot639_5.jpg', 'id': 11, 'width': 608, 'height': 608},
#   {'file_name': 'shoot639_8.jpg', 'id': 12, 'width': 608, 'height': 608},
#   {'file_name': 'shoot639_9.jpg', 'id': 13, 'width': 608, 'height': 608},
#   {'file_name': 'shoot640_4.jpg', 'id': 14, 'width': 608, 'height': 608},
#   {'file_name': 'shoot640_5.jpg', 'id': 15, 'width': 608, 'height': 608},
#   {'file_name': 'shoot641_3.jpg', 'id': 16, 'width': 608, 'height': 608},
#   {'file_name': 'shoot641_5.jpg', 'id': 17, 'width': 608, 'height': 608},
#   {'file_name': 'shoot642_5.jpg', 'id': 18, 'width': 608, 'height': 608},
#   {'file_name': 'shoot642_7.jpg', 'id': 19, 'width': 608, 'height': 608},
#   {'file_name': 'shoot644_4.jpg', 'id': 20, 'width': 608, 'height': 608},
#   {'file_name': 'shoot645_1.jpg', 'id': 21, 'width': 608, 'height': 608},
#   {'file_name': 'shoot645_5.jpg', 'id': 22, 'width': 608, 'height': 608},
#   {'file_name': 'shoot649_5.jpg', 'id': 23, 'width': 608, 'height': 608},
#   {'file_name': 'shoot649_6.jpg', 'id': 24, 'width': 608, 'height': 608},
#   {'file_name': 'shoot650_2.jpg', 'id': 25, 'width': 608, 'height': 608},
#   {'file_name': 'shoot650_5.jpg', 'id': 26, 'width': 608, 'height': 608},
#   {'file_name': 'shoot651_4.jpg', 'id': 27, 'width': 608, 'height': 608},
#   {'file_name': 'shoot651_8.jpg', 'id': 28, 'width': 608, 'height': 608},
#   {'file_name': 'shoot652_5.jpg', 'id': 29, 'width': 608, 'height': 608},
#   {'file_name': 'shoot653_5.jpg', 'id': 30, 'width': 608, 'height': 608},
#   {'file_name': 'shoot654_5.jpg', 'id': 31, 'width': 608, 'height': 608},
#   {'file_name': 'shoot658_3.jpg', 'id': 32, 'width': 608, 'height': 608},
#   {'file_name': 'shoot658_5.jpg', 'id': 33, 'width': 608, 'height': 608},
#   {'file_name': 'shoot659_1.jpg', 'id': 34, 'width': 608, 'height': 608},
#   {'file_name': 'shoot660_5.jpg', 'id': 35, 'width': 608, 'height': 608},
#   {'file_name': 'shoot660_8.jpg', 'id': 36, 'width': 608, 'height': 608},
#   {'file_name': 'shoot664_5.jpg', 'id': 37, 'width': 608, 'height': 608},
#   {'file_name': 'shoot670_5.jpg', 'id': 38, 'width': 608, 'height': 608},
#   {'file_name': 'shoot676_9.jpg', 'id': 39, 'width': 608, 'height': 608},
#   {'file_name': 'shoot677_2.jpg', 'id': 40, 'width': 608, 'height': 608},
#   {'file_name': 'shoot678_5.jpg', 'id': 41, 'width': 608, 'height': 608},
#   {'file_name': 'shoot679_9.jpg', 'id': 42, 'width': 608, 'height': 608},
#   {'file_name': 'shoot680_1.jpg', 'id': 43, 'width': 608, 'height': 608},
#   {'file_name': 'shoot680_6.jpg', 'id': 44, 'width': 608, 'height': 608},
#   {'file_name': 'shoot681_5.jpg', 'id': 45, 'width': 608, 'height': 608},
#   {'file_name': 'shoot683_5.jpg', 'id': 46, 'width': 608, 'height': 608},
#   {'file_name': 'shoot684_8.jpg', 'id': 47, 'width': 608, 'height': 608},
#   {'file_name': 'shoot685_9.jpg', 'id': 48, 'width': 608, 'height': 608},
#   {'file_name': 'shoot686_2.jpg', 'id': 49, 'width': 608, 'height': 608},
#   {'file_name': 'shoot686_5.jpg', 'id': 50, 'width': 608, 'height': 608},
#   {'file_name': 'shoot686_9.jpg', 'id': 51, 'width': 608, 'height': 608},
#   {'file_name': 'shoot690_5.jpg', 'id': 52, 'width': 608, 'height': 608},
#   {'file_name': 'shoot690_6.jpg', 'id': 53, 'width': 608, 'height': 608},
#   {'file_name': 'shoot692_6.jpg', 'id': 54, 'width': 608, 'height': 608},
#   {'file_name': 'shoot694_8.jpg', 'id': 55, 'width': 608, 'height': 608},
#   {'file_name': 'shoot701_8.jpg', 'id': 56, 'width': 608, 'height': 608},
#   {'file_name': 'shoot703_5.jpg', 'id': 57, 'width': 608, 'height': 608},
#   {'file_name': 'shoot703_7.jpg', 'id': 58, 'width': 608, 'height': 608},
#   {'file_name': 'shoot703_9.jpg', 'id': 59, 'width': 608, 'height': 608},
#   {'file_name': 'shoot705_5.jpg', 'id': 60, 'width': 608, 'height': 608},
#   {'file_name': 'shoot706_5.jpg', 'id': 61, 'width': 608, 'height': 608}]}
